# %%
# Install Libries
import pandas as pd 
import numpy as np 
import requests

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# # Economic Data

# %%
import time
Economic_Prosperity = [
    "NY.GDP.PCAP.CD",       # GDP per capita (current US$)
    "NY.GDP.PCAP.PP.CD",   # GDP per capita, PPP (current international $)
    "NY.GDP.MKTP.KD.ZG",   # GDP growth (annual %)
    "NY.GDP.MKTP.CD",       # GDP (current US$)
    "SL.UEM.TOTL.ZS",       # Unemployment, total (% of labor force)
    "SL.EMP.TOTL.SP.ZS",    # Employment-to-population ratio (% ages 15+)
    "FP.CPI.TOTL.ZG",       # Inflation, consumer prices (annual %)
    "NE.EXP.GNFS.ZS",       # Exports of goods & services (% of GDP)
    "NE.IMP.GNFS.ZS" ]    # Imports of goods & services (% of GDP)


base_url = "https://api.worldbank.org/v2/countries/all/indicators/{}?format=json&per_page=1000&page={}"
indicator_dataframe = {}
for i in Economic_Prosperity:
  print(f"Fetching Data For indicator : {i}")

  all_dfs = []
  page = 1
  fault = 1
  while True:
    url = base_url.format(i,page)
    response = requests.get(url)

    if response.status_code!=200:
      if fault>2:
        break
      else:
        print(f"No Data for Page : {page}")
        page +=1
        fault += 1
        continue
    else:

      try:
        data = response.json()
      except Exception as e:
        if fault>2:
          break
        else:
          print(f"{e} Error while Loading page : {page}")
          page += 1
          fault += 1
          continue

      if len(data)<2 or not data[1]:
        if fault>2:
          break
        else:
          print(f"No Data For Indicator {i} on page {page}")
          page += 1
          fault += 1
          continue

      print(f"Page : {page} fetched for indicator {i}")

      total_pages = data[0]['pages']
      record = data[1]

      if page>total_pages:
        print(f"Current Page : {page} | Total Page : {total_pages}")
        break
      else:
        df = pd.json_normalize(record)
        df = df[[ "country.id","country.value","indicator.id","indicator.value","date","value"]].rename(columns={
                "country.id":"country_id",
                "country.value":"country_value","indicator.id":"indicator_id","indicator.value":"indicator_name","date":"year"})

        df = df[df["year"].astype(int) > 2000]
        all_dfs.append(df)

        page += 1
        time.sleep(0.3)

  if all_dfs:

    combined_df = pd.concat(all_dfs, ignore_index=True)
    indicator_dataframe[i] = combined_df
    print(f"📊 Total rows collected for {i}: {len(combined_df)}")
  else:
    print(f"⚠️ No data collected for {i}")
# Out:
# Fetching Data For indicator : NY.GDP.PCAP.CD
# Page : 1 fetched for indicator NY.GDP.PCAP.CD
# Page : 2 fetched for indicator NY.GDP.PCAP.CD
# Page : 3 fetched for indicator NY.GDP.PCAP.CD
# Page : 4 fetched for indicator NY.GDP.PCAP.CD
# Page : 5 fetched for indicator NY.GDP.PCAP.CD
# Page : 6 fetched for indicator NY.GDP.PCAP.CD
# Page : 7 fetched for indicator NY.GDP.PCAP.CD
# Page : 8 fetched for indicator NY.GDP.PCAP.CD
# Page : 9 fetched for indicator NY.GDP.PCAP.CD
# Page : 10 fetched for indicator NY.GDP.PCAP.CD
# Page : 11 fetched for indicator NY.GDP.PCAP.CD
# Page : 12 fetched for indicator NY.GDP.PCAP.CD
# Page : 13 fetched for indicator NY.GDP.PCAP.CD
# Page : 14 fetched for indicator NY.GDP.PCAP.CD
# Page : 15 fetched for indicator NY.GDP.PCAP.CD
# Page : 16 fetched for indicator NY.GDP.PCAP.CD
# Page : 17 fetched for indicator NY.GDP.PCAP.CD
# Page : 18 fetched for indicator NY.GDP.PCAP.CD
# No Data For Indicator NY.GDP.PCAP.CD on page 19
# No Data For Indicator NY.GDP.PCAP.CD on page 20
# 📊 Total rows collected for NY.GDP.PCAP.CD: 6384
# Fetching Data For indicator : NY.GDP.PCAP.PP.CD
# Page : 1 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 2 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 3 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 4 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 5 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 6 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 7 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 8 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 9 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 10 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 11 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 12 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 13 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 14 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 15 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 16 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 17 fetched for indicator NY.GDP.PCAP.PP.CD
# Page : 18 fetched for indicator NY.GDP.PCAP.PP.CD
# No Data For Indicator NY.GDP.PCAP.PP.CD on page 19
# No Data For Indicator NY.GDP.PCAP.PP.CD on page 20
# 📊 Total rows collected for NY.GDP.PCAP.PP.CD: 6384
# Fetching Data For indicator : NY.GDP.MKTP.KD.ZG
# Page : 1 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 2 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 3 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 4 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 5 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 6 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 7 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 8 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 9 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 10 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 11 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 12 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 13 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 14 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 15 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 16 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 17 fetched for indicator NY.GDP.MKTP.KD.ZG
# Page : 18 fetched for indicator NY.GDP.MKTP.KD.ZG
# No Data For Indicator NY.GDP.MKTP.KD.ZG on page 19
# No Data For Indicator NY.GDP.MKTP.KD.ZG on page 20
# 📊 Total rows collected for NY.GDP.MKTP.KD.ZG: 6384
# Fetching Data For indicator : NY.GDP.MKTP.CD
# Page : 1 fetched for indicator NY.GDP.MKTP.CD
# Page : 2 fetched for indicator NY.GDP.MKTP.CD
# Page : 3 fetched for indicator NY.GDP.MKTP.CD
# Page : 4 fetched for indicator NY.GDP.MKTP.CD
# Page : 5 fetched for indicator NY.GDP.MKTP.CD
# Page : 6 fetched for indicator NY.GDP.MKTP.CD
# Page : 7 fetched for indicator NY.GDP.MKTP.CD
# Page : 8 fetched for indicator NY.GDP.MKTP.CD
# Page : 9 fetched for indicator NY.GDP.MKTP.CD
# Page : 10 fetched for indicator NY.GDP.MKTP.CD
# Page : 11 fetched for indicator NY.GDP.MKTP.CD
# Page : 12 fetched for indicator NY.GDP.MKTP.CD
# Page : 13 fetched for indicator NY.GDP.MKTP.CD
# Page : 14 fetched for indicator NY.GDP.MKTP.CD
# Page : 15 fetched for indicator NY.GDP.MKTP.CD
# Page : 16 fetched for indicator NY.GDP.MKTP.CD
# Page : 17 fetched for indicator NY.GDP.MKTP.CD
# Page : 18 fetched for indicator NY.GDP.MKTP.CD
# No Data For Indicator NY.GDP.MKTP.CD on page 19
# No Data For Indicator NY.GDP.MKTP.CD on page 20
# 📊 Total rows collected for NY.GDP.MKTP.CD: 6384
# Fetching Data For indicator : SL.UEM.TOTL.ZS
# Page : 1 fetched for indicator SL.UEM.TOTL.ZS
# Page : 2 fetched for indicator SL.UEM.TOTL.ZS
# Page : 3 fetched for indicator SL.UEM.TOTL.ZS
# Page : 4 fetched for indicator SL.UEM.TOTL.ZS
# Page : 5 fetched for indicator SL.UEM.TOTL.ZS
# Page : 6 fetched for indicator SL.UEM.TOTL.ZS
# Page : 7 fetched for indicator SL.UEM.TOTL.ZS
# Page : 8 fetched for indicator SL.UEM.TOTL.ZS
# Page : 9 fetched for indicator SL.UEM.TOTL.ZS
# Page : 10 fetched for indicator SL.UEM.TOTL.ZS
# Page : 11 fetched for indicator SL.UEM.TOTL.ZS
# Page : 12 fetched for indicator SL.UEM.TOTL.ZS
# Page : 13 fetched for indicator SL.UEM.TOTL.ZS
# Page : 14 fetched for indicator SL.UEM.TOTL.ZS
# Page : 15 fetched for indicator SL.UEM.TOTL.ZS
# Page : 16 fetched for indicator SL.UEM.TOTL.ZS
# Page : 17 fetched for indicator SL.UEM.TOTL.ZS
# Page : 18 fetched for indicator SL.UEM.TOTL.ZS
# No Data For Indicator SL.UEM.TOTL.ZS on page 19
# No Data For Indicator SL.UEM.TOTL.ZS on page 20
# 📊 Total rows collected for SL.UEM.TOTL.ZS: 6384
# Fetching Data For indicator : SL.EMP.TOTL.SP.ZS
# Page : 1 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 2 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 3 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 4 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 5 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 6 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 7 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 8 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 9 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 10 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 11 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 12 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 13 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 14 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 15 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 16 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 17 fetched for indicator SL.EMP.TOTL.SP.ZS
# Page : 18 fetched for indicator SL.EMP.TOTL.SP.ZS
# No Data For Indicator SL.EMP.TOTL.SP.ZS on page 19
# No Data For Indicator SL.EMP.TOTL.SP.ZS on page 20
# 📊 Total rows collected for SL.EMP.TOTL.SP.ZS: 6384
# Fetching Data For indicator : FP.CPI.TOTL.ZG
# Page : 1 fetched for indicator FP.CPI.TOTL.ZG
# Page : 2 fetched for indicator FP.CPI.TOTL.ZG
# Page : 3 fetched for indicator FP.CPI.TOTL.ZG
# Page : 4 fetched for indicator FP.CPI.TOTL.ZG
# Page : 5 fetched for indicator FP.CPI.TOTL.ZG
# Page : 6 fetched for indicator FP.CPI.TOTL.ZG
# Page : 7 fetched for indicator FP.CPI.TOTL.ZG
# Page : 8 fetched for indicator FP.CPI.TOTL.ZG
# Page : 9 fetched for indicator FP.CPI.TOTL.ZG
# Page : 10 fetched for indicator FP.CPI.TOTL.ZG
# Page : 11 fetched for indicator FP.CPI.TOTL.ZG
# Page : 12 fetched for indicator FP.CPI.TOTL.ZG
# Page : 13 fetched for indicator FP.CPI.TOTL.ZG
# Page : 14 fetched for indicator FP.CPI.TOTL.ZG
# Page : 15 fetched for indicator FP.CPI.TOTL.ZG
# Page : 16 fetched for indicator FP.CPI.TOTL.ZG
# Page : 17 fetched for indicator FP.CPI.TOTL.ZG
# Page : 18 fetched for indicator FP.CPI.TOTL.ZG
# No Data For Indicator FP.CPI.TOTL.ZG on page 19
# No Data For Indicator FP.CPI.TOTL.ZG on page 20
# 📊 Total rows collected for FP.CPI.TOTL.ZG: 6384
# Fetching Data For indicator : NE.EXP.GNFS.ZS
# Page : 1 fetched for indicator NE.EXP.GNFS.ZS
# Page : 2 fetched for indicator NE.EXP.GNFS.ZS
# Page : 3 fetched for indicator NE.EXP.GNFS.ZS
# Page : 4 fetched for indicator NE.EXP.GNFS.ZS
# Page : 5 fetched for indicator NE.EXP.GNFS.ZS
# Page : 6 fetched for indicator NE.EXP.GNFS.ZS
# Page : 7 fetched for indicator NE.EXP.GNFS.ZS
# Page : 8 fetched for indicator NE.EXP.GNFS.ZS
# Page : 9 fetched for indicator NE.EXP.GNFS.ZS
# Page : 10 fetched for indicator NE.EXP.GNFS.ZS
# Page : 11 fetched for indicator NE.EXP.GNFS.ZS
# Page : 12 fetched for indicator NE.EXP.GNFS.ZS
# Page : 13 fetched for indicator NE.EXP.GNFS.ZS
# Page : 14 fetched for indicator NE.EXP.GNFS.ZS
# Page : 15 fetched for indicator NE.EXP.GNFS.ZS
# Page : 16 fetched for indicator NE.EXP.GNFS.ZS
# Page : 17 fetched for indicator NE.EXP.GNFS.ZS
# Page : 18 fetched for indicator NE.EXP.GNFS.ZS
# No Data For Indicator NE.EXP.GNFS.ZS on page 19
# No Data For Indicator NE.EXP.GNFS.ZS on page 20
# 📊 Total rows collected for NE.EXP.GNFS.ZS: 6384
# Fetching Data For indicator : NE.IMP.GNFS.ZS
# Page : 1 fetched for indicator NE.IMP.GNFS.ZS
# Page : 2 fetched for indicator NE.IMP.GNFS.ZS
# Page : 3 fetched for indicator NE.IMP.GNFS.ZS
# Page : 4 fetched for indicator NE.IMP.GNFS.ZS
# Page : 5 fetched for indicator NE.IMP.GNFS.ZS
# Page : 6 fetched for indicator NE.IMP.GNFS.ZS
# Page : 7 fetched for indicator NE.IMP.GNFS.ZS
# Page : 8 fetched for indicator NE.IMP.GNFS.ZS
# Page : 9 fetched for indicator NE.IMP.GNFS.ZS
# Page : 10 fetched for indicator NE.IMP.GNFS.ZS
# Page : 11 fetched for indicator NE.IMP.GNFS.ZS
# Page : 12 fetched for indicator NE.IMP.GNFS.ZS
# Page : 13 fetched for indicator NE.IMP.GNFS.ZS
# Page : 14 fetched for indicator NE.IMP.GNFS.ZS
# Page : 15 fetched for indicator NE.IMP.GNFS.ZS
# Page : 16 fetched for indicator NE.IMP.GNFS.ZS
# Page : 17 fetched for indicator NE.IMP.GNFS.ZS
# Page : 18 fetched for indicator NE.IMP.GNFS.ZS
# No Data For Indicator NE.IMP.GNFS.ZS on page 19
# No Data For Indicator NE.IMP.GNFS.ZS on page 20
# 📊 Total rows collected for NE.IMP.GNFS.ZS: 6384

# %%
all_indicators = []
for key, df in indicator_dataframe.items():
    temp = df[['indicator_name',"country_value", "year", "value"]].copy()
    all_indicators.append(temp)

# %%
indicator_dataframe['NY.GDP.MKTP.CD']['country_value'].unique().shape
# Out:
# (266,)

# %%
all_indicators = pd.concat(all_indicators)
wide_indicators = all_indicators.pivot_table(
    index=["country_value", "year"],
    columns="indicator_name",
    values="value"
).reset_index()

# %%
wide_indicators
# Out:
# indicator_name country_value  year  \
# 0                Afghanistan  2001
# 1                Afghanistan  2002
# 2                Afghanistan  2003
# 3                Afghanistan  2004
# 4                Afghanistan  2005
# ...                      ...   ...
# 6264                Zimbabwe  2020
# 6265                Zimbabwe  2021
# 6266                Zimbabwe  2022
# 6267                Zimbabwe  2023
# 6268                Zimbabwe  2024
#
# indicator_name  Employment to population ratio, 15+, total (%) (modeled ILO estimate)  \
# 0                                                          42.832
# 1                                                          42.820
# 2                                                          42.835
# 3                                                          42.833
# 4                                                          42.863
# ...                                                           ...
# 6264                                                       59.180
# 6265                                                       59.159
# 6266                                                       58.636
# 6267                                                       59.308
# 6268                                                       59.379
#
# indicator_name  Exports of goods and services (% of GDP)  GDP (current US$)  \
# 0                                                    NaN       2.813572e+09
# 1                                                    NaN       3.825701e+09
# 2                                                    NaN       4.520947e+09
# 3                                                    NaN       5.224897e+09
# 4                                                    NaN       6.203257e+09
# ...                                                  ...                ...
# 6264                                           22.293071       2.686856e+10
# 6265                                           22.775238       2.724051e+10
# 6266                                           27.872170       3.278966e+10
# 6267                                           21.579400       3.523137e+10
# 6268                                           22.105677       4.418770e+10
#
# indicator_name  GDP growth (annual %)  GDP per capita (current US$)  \
# 0                           -9.431974                    138.706822
# 1                           28.600001                    178.954088
# 2                            8.832278                    198.871116
# 3                            1.414118                    221.763654
# 4                           11.229715                    254.184249
# ...                               ...                           ...
# 6264                        -7.816933                   1730.453910
# 6265                         8.468039                   1724.387271
# 6266                         6.139176                   2040.546587
# 6267                         5.336770                   2156.034093
# 6268                         2.029484                   2656.409377
#
# indicator_name  GDP per capita, PPP (current international $)  \
# 0                                                  747.688045
# 1                                                  926.507941
# 2                                                  966.962032
# 3                                                  971.633503
# 4                                                 1076.087353
# ...                                                       ...
# 6264                                              3510.676040
# 6265                                              3184.784602
# 6266                                              3560.039403
# 6267                                              3820.359922
# 6268                                              3921.697956
#
# indicator_name  Imports of goods and services (% of GDP)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 6264                                           25.020311
# 6265                                           28.071885
# 6266                                           36.891437
# 6267                                           29.215564
# 6268                                           30.567336
#
# indicator_name  Inflation, consumer prices (annual %)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                           12.686269
# ...                                               ...
# 6264                                       557.201817
# 6265                                        98.546105
# 6266                                       104.705171
# 6267                                              NaN
# 6268                                              NaN
#
# indicator_name  Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                           7.953
# 1                                                           7.930
# 2                                                           7.880
# 3                                                           7.899
# 4                                                           7.885
# ...                                                           ...
# 6264                                                        8.621
# 6265                                                        9.540
# 6266                                                       10.087
# 6267                                                        8.759
# 6268                                                        8.554
#
# [6269 rows x 11 columns]

# %%
wide_indicators.columns
# Out:
# Index(['country_value', 'year',
#        'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
#        'Exports of goods and services (% of GDP)', 'GDP (current US$)',
#        'GDP growth (annual %)', 'GDP per capita (current US$)',
#        'GDP per capita, PPP (current international $)',
#        'Imports of goods and services (% of GDP)',
#        'Inflation, consumer prices (annual %)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)'],
#       dtype='object', name='indicator_name')

# %%
wide_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6269 entries, 0 to 6268
# Data columns (total 11 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   country_value                                                          6269 non-null   object
#  1   year                                                                   6269 non-null   object
#  2   Employment to population ratio, 15+, total (%) (modeled ILO estimate)  5631 non-null   float64
#  3   Exports of goods and services (% of GDP)                               5317 non-null   float64
#  4   GDP (current US$)                                                      6161 non-null   float64
#  5   GDP growth (annual %)                                                  6094 non-null   float64
#  6   GDP per capita (current US$)                                           6167 non-null   float64
#  7   GDP per capita, PPP (current international $)                          5892 non-null   float64
#  8   Imports of goods and services (% of GDP)                               5365 non-null   float64
#  9   Inflation, consumer prices (annual %)                                  5472 non-null   float64
#  10  Unemployment, total (% of total labor force) (modeled ILO estimate)    5631 non-null   float64
# dtypes: float64(9), object(2)
# memory usage: 538.9+ KB

# %%
# cols = [
#     'Exports of goods and services (% of GDP)',
#     'GDP (current US$)',
#     'GDP growth (annual %)',
#     'GDP per capita (current US$)',
#     'GDP per capita, PPP (current international $)',
#     'Imports of goods and services (% of GDP)',
#     'Inflation, consumer prices (annual %)'
# ]

# # Check rows where all of these columns are null
# all_null = wide_indicators[cols].isnull().all(axis=1)

# # Show rows where all are null
# wide_indicators[all_null]

# %%
# idx = wide_indicators[all_null].index
# wide_indicators = wide_indicators.drop(idx)

# %%
wide_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6204 entries, 0 to 6268
# Data columns (total 11 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   country_value                                                          6204 non-null   object
#  1   year                                                                   6204 non-null   object
#  2   Employment to population ratio, 15+, total (%) (modeled ILO estimate)  5566 non-null   float64
#  3   Exports of goods and services (% of GDP)                               5317 non-null   float64
#  4   GDP (current US$)                                                      6161 non-null   float64
#  5   GDP growth (annual %)                                                  6094 non-null   float64
#  6   GDP per capita (current US$)                                           6167 non-null   float64
#  7   GDP per capita, PPP (current international $)                          5892 non-null   float64
#  8   Imports of goods and services (% of GDP)                               5365 non-null   float64
#  9   Inflation, consumer prices (annual %)                                  5472 non-null   float64
#  10  Unemployment, total (% of total labor force) (modeled ILO estimate)    5566 non-null   float64
# dtypes: float64(9), object(2)
# memory usage: 581.6+ KB

# %%
# a = wide_indicators.dropna(thresh=len(wide_indicators.columns) - 4 + 1)
# a['year'].value_counts().sort_index()

# %%
# wide_indicators = wide_indicators.fillna(-1.0)

# %%
#Save Data
wide_indicators.to_csv("Economic_df.csv",index=False)
